# %%
import os

from datetime import datetime

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import sys
sys.path.append('../')

from nc_explorer import NcExplorer
import utils

# %%
work_dir = '/d_drive_data/L2_WFR'

field_files = os.listdir(work_dir)

# just in case we want to take a look at all the file names
# [print(f"{datetime.strptime(ff[16:31], '%Y%m%dT%H%M%S')} :: {ff}") for ff in field_files]

print(field_files[0:5])
# Out:
# ['S3A_OL_2_WFR____20190309T141223_20190309T141523_20190310T211622_0179_042_167_3060_MAR_O_NT_002.SEN3', 'S3A_OL_2_WFR____20190310T134612_20190310T134912_20190311T222357_0180_042_181_3060_MAR_O_NT_002.SEN3', 'S3A_OL_2_WFR____20190313T140838_20190313T141138_20190314T214804_0179_042_224_3060_MAR_O_NT_002.SEN3', 'S3A_OL_2_WFR____20190314T134227_20190314T134527_20190315T222121_0179_042_238_3060_MAR_O_NT_002.SEN3', 'S3A_OL_2_WFR____20190410T134233_20190410T134533_20190411T220636_0179_043_238_3060_MAR_O_NT_002.SEN3']

# %%
# SETING UP THE CONSTANTS

exp = NcExplorer(verbose=True)

# Manacapuru
query_lon, query_lat = -60.571213, -3.325576 

b8 = 'Oa08_reflectance.nc'
b17 = 'Oa17_reflectance.nc'
# Out:
# Declaring class instance from: S3-FRBR:Nc_Explorer
# Verbose set to True.
# Input NetCDF file folde not set. Proceed at your own risk.

# %% [markdown]
# ## Testing with single band Oa8_radiance.nc

# %%
file_name = os.path.join(work_dir, field_files[0])

exp.nc_folder = file_name

lon, lat = exp.get_lon_lat_from_nc()

b8data = exp.extract_data_from_single_band(b8)

mat_pos_in_xy, value_in_xy = exp.get_point_data_in_single_band(b8data, lon, lat, query_lon, query_lat)

print(mat_pos_in_xy, value_in_xy)
# Out:
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190309T141223_20190309T141523_20190310T211622_0179_042_167_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:0s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa17_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# (232, 4864) --

# %% [markdown]
# ## Repeating the process for all 209 WFR L2 images

# %%
b8_time_series = []

for image in field_files:
        
    file_name = os.path.join(work_dir, image)
    
    exp.nc_folder = file_name

    lon, lat = exp.get_lon_lat_from_nc()

    b8data = exp.extract_data_from_single_band(b8)

    mat_pos_in_xy, value_in_xy = exp.get_point_data_in_single_band(b8data, lon, lat, query_lon, query_lat)

    b8_time_series.append(value_in_xy)
# Out:
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190309T141223_20190309T141523_20190310T211622_0179_042_167_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190310T134612_20190310T134912_20190311T222357_0180_042_181_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4090, 4865), size: 19897850
# Latitude shape: (4090, 4865), size: 19897850
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190313T140838_20190313T141138_20190314T214804_0179_042_224_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4090, 4865), size: 19897850
# Latitude shape: (4090, 4865), size: 19897850
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190314T134227_20190314T134527_20190315T222121_0179_042_238_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190410T134233_20190410T134533_20190411T220636_0179_043_238_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190413T140500_20190413T140800_20190414T215002_0179_043_281_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190414T133849_20190414T134149_20190415T223334_0180_043_295_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190426T132738_20190426T133038_20190427T210231_0179_044_081_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190429T135004_20190429T135304_20190430T223659_0179_044_124_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190430T132354_20190430T132654_20190501T214159_0179_044_138_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190511T133852_20190511T134152_20190512T222102_0180_044_295_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190514T140118_20190514T140418_20190515T232652_0180_044_338_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190515T133507_20190515T133807_20190516T225445_0179_044_352_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190317T140455_20190317T140755_20190318T205900_0179_042_281_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20190326T133117_20190326T133417_20190327T220644_0179_043_024_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3A_OL_2_WFR____20
167_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4090, 4865), size: 19897850
# Latitude shape: (4090, 4865), size: 19897850
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190909T140250_20190909T140550_20190911T001620_0180_029_338_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190910T133639_20190910T133939_20190911T201548_0179_029_352_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190913T135906_20190913T140206_20190914T223601_0179_030_010_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190924T141403_20190924T141703_20190925T230431_0180_030_167_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190925T134752_20190925T135052_20190926T224651_0179_030_181_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190928T141018_20190928T141318_20190929T224828_0179_030_224_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4090, 4865), size: 19897850
# Latitude shape: (4090, 4865), size: 19897850
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()
#
# S3-FRBR:Nc_Explorer.get_lon_lat_from_nc()
#
# Extracting Lon/Lat dataframes from:
# /d_drive_data/L2_WFR/S3B_OL_2_WFR____20190929T134407_20190929T134707_20190930T223218_0179_030_238_3060_MAR_O_NT_002.SEN3
#
# Longitude shape: (4091, 4865), size: 19902715
# Latitude shape: (4091, 4865), size: 19902715
#
# Done in 0h:0m:1s
# S3-FRBR:Nc_Explorer.extract_data_from_single_band()
#
# extracting band: Oa08_reflectance.nc
#
# Done in 0h:0m:0s
#
# S3-FRBR:Nc_Explorer.get_point_data_in_single_band()

# %%
len(b8_time_series)
# Out:
# 209

# %%
plt.rcParams['figure.figsize'] = [12, 6] 
plt.plot(b8_time_series)

# %%
import numpy.ma as ma
mab8 = ma.array(b8_time_series)

print(len(b8_time_series)-ma.count_masked(mab8))

print(ma.count_masked(mab8))
# Out:
# 93
# 116

# %% [markdown]
# ## Using internal module to connect to external tools

# %%
import outsourcing as out

gpt = out.GPTBridge('/d_drive_data/snap/bin/gpt', '/d_drive_data/processing/MANACAPURU/')
gpt
# Out:
# gpt_bridge class instance using gpt: /d_drive_data/snap/bin/gpt and output: /d_drive_data/processing/MANACAPURU/ as CSV

# %%
total = len(field_files)
for n, image in enumerate(field_files):
    
    file_name = os.path.join(work_dir, image)

    print(f'Processing image {n} of {total}:\n{image}\n')

    gpt.get_pixels_by_kml('/d_drive_data/A1_JM/manacapuru.kml', file_name)
# Out:
# Processing image 0 of 209:
# S3A_OL_2_WFR____20190309T141223_20190309T141523_20190310T211622_0179_042_167_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190309T141223_20190309T141523_20190310T211622_0179_042_167_3060_MAR_O_NT_002  Created
# Processing image 1 of 209:
# S3A_OL_2_WFR____20190310T134612_20190310T134912_20190311T222357_0180_042_181_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190310T134612_20190310T134912_20190311T222357_0180_042_181_3060_MAR_O_NT_002  Created
# Processing image 2 of 209:
# S3A_OL_2_WFR____20190313T140838_20190313T141138_20190314T214804_0179_042_224_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190313T140838_20190313T141138_20190314T214804_0179_042_224_3060_MAR_O_NT_002  Created
# Processing image 3 of 209:
# S3A_OL_2_WFR____20190314T134227_20190314T134527_20190315T222121_0179_042_238_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190314T134227_20190314T134527_20190315T222121_0179_042_238_3060_MAR_O_NT_002  Created
# Processing image 4 of 209:
# S3A_OL_2_WFR____20190410T134233_20190410T134533_20190411T220636_0179_043_238_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190410T134233_20190410T134533_20190411T220636_0179_043_238_3060_MAR_O_NT_002  Created
# Processing image 5 of 209:
# S3A_OL_2_WFR____20190413T140500_20190413T140800_20190414T215002_0179_043_281_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20190413T140500_20190413T140800_20190414T215002_0179_043_281_3060_MAR_O_NT_002  Created
# Processing image 6 of 209:
# S3A_OL_2_WFR____20190414T133849_20190414T134149_20190415T223334_0180_043_295_3060_MAR_O_NT_002.SEN3
#
# Directory  /d_drive_data/processing/MANACAPURU/AUX_S3A_OL_2_WFR____20
df = pd.read_csv(image_path, sep='\t', skiprows=1)

# %%
df.head()
# Out:
#    featureId  Oa01_reflectance:float  Oa01_reflectance_err:float  \
# 0          0                1.000018                    1.000018
# 1          1                1.000018                    1.000018
# 2          2                1.000018                    1.000018
# 3          3                1.000018                    1.000018
# 4          4                1.000018                    1.000018
#
#    Oa02_reflectance:float  Oa02_reflectance_err:float  Oa03_reflectance:float  \
# 0                1.000018                    1.000018                1.000018
# 1                1.000018                    1.000018                1.000018
# 2                1.000018                    1.000018                1.000018
# 3                1.000018                    1.000018                1.000018
# 4                1.000018                    1.000018                1.000018
#
#    Oa03_reflectance_err:float  Oa04_reflectance:float  \
# 0                    1.000018                1.000018
# 1                    1.000018                1.000018
# 2                    1.000018                1.000018
# 3                    1.000018                1.000018
# 4                    1.000018                1.000018
#
#    Oa04_reflectance_err:float  Oa05_reflectance:float  ...  \
# 0                    1.000018                1.000018  ...
# 1                    1.000018                1.000018  ...
# 2                    1.000018                1.000018  ...
# 3                    1.000018                1.000018  ...
# 4                    1.000018                1.000018  ...
#
#    atmospheric_temperature_profile_pressure_level_22:float  \
# 0                                          237.85246
# 1                                          237.85060
# 2                                          237.84874
# 3                                          237.84688
# 4                                          237.84502
#
#    atmospheric_temperature_profile_pressure_level_23:float  \
# 0                                          246.07849
# 1                                          246.07362
# 2                                          246.06876
# 3                                          246.06389
# 4                                          246.05902
#
#    atmospheric_temperature_profile_pressure_level_24:float  \
# 0                                          270.71906
# 1                                          270.71497
# 2                                          270.71088
# 3                                          270.70682
# 4                                          270.70273
#
#    atmospheric_temperature_profile_pressure_level_25:float  \
# 0                                          259.65442
# 1                                          259.65723
# 2                                          259.66003
# 3                                          259.66284
# 4                                          259.66562
#
#    horizontal_wind_vector_1:float  horizontal_wind_vector_2:float  \
# 0                       -2.188041                        1.104665
# 1                       -2.192788                        1.104195
# 2                       -2.197534                        1.103726
# 3                       -2.202281                        1.103256
# 4                       -2.207027                        1.102787
#
#    humidity:float  sea_level_pressure:float  \
# 0       66.574740                1012.01294
# 1       66.582054                1012.01245
# 2       66.589380                1012.01196
# 3       66.596695                1012.01150
# 4       66.604020                1012.01100
#
#    total_columnar_water_vapour:float  total_ozone:float
# 0                          48.955600           0.005643
# 1                          48.966100           0.005643
# 2                          48.976597           0.005643
# 3                          48.987095           0.005643
# 4                          48.997597           0.005643
#
# [5 rows x 158 columns]

# %%
# too much columns...
df.columns.values
# Out:
# array(['featureId', 'Oa01_reflectance:float',
#        'Oa01_reflectance_err:float', 'Oa02_reflectance:float',
#        'Oa02_reflectance_err:float', 'Oa03_reflectance:float',
#        'Oa03_reflectance_err:float', 'Oa04_reflectance:float',
#        'Oa04_reflectance_err:float', 'Oa05_reflectance:float',
#        'Oa05_reflectance_err:float', 'Oa06_reflectance:float',
#        'Oa06_reflectance_err:float', 'Oa07_reflectance:float',
#        'Oa07_reflectance_err:float', 'Oa08_reflectance:float',
#        'Oa08_reflectance_err:float', 'Oa09_reflectance:float',
#        'Oa09_reflectance_err:float', 'Oa10_reflectance:float',
#        'Oa10_reflectance_err:float', 'Oa11_reflectance:float',
#        'Oa11_reflectance_err:float', 'Oa12_reflectance:float',
#        'Oa12_reflectance_err:float', 'Oa16_reflectance:float',
#        'Oa16_reflectance_err:float', 'Oa17_reflectance:float',
#        'Oa17_reflectance_err:float', 'Oa18_reflectance:float',
#        'Oa18_reflectance_err:float', 'Oa21_reflectance:float',
#        'Oa21_reflectance_err:float', 'CHL_NN:float', 'CHL_NN_err:float',
#        'CHL_OC4ME:float', 'CHL_OC4ME_err:float', 'altitude:short',
#        'latitude:double', 'longitude:double', 'detector_index:short',
#        'FWHM_band_1:float', 'FWHM_band_2:float', 'FWHM_band_3:float',
#        'FWHM_band_4:float', 'FWHM_band_5:float', 'FWHM_band_6:float',
#        'FWHM_band_7:float', 'FWHM_band_8:float', 'FWHM_band_9:float',
#        'FWHM_band_10:float', 'FWHM_band_11:float', 'FWHM_band_12:float',
#        'FWHM_band_13:float', 'FWHM_band_14:float', 'FWHM_band_15:float',
#        'FWHM_band_16:float', 'FWHM_band_17:float', 'FWHM_band_18:float',
#        'FWHM_band_19:float', 'FWHM_band_20:float', 'FWHM_band_21:float',
#        'frame_offset:short', 'lambda0_band_1:float',
#        'lambda0_band_2:float', 'lambda0_band_3:float',
#        'lambda0_band_4:float', 'lambda0_band_5:float',
#        'lambda0_band_6:float', 'lambda0_band_7:float',
#        'lambda0_band_8:float', 'lambda0_band_9:float',
#        'lambda0_band_10:float', 'lambda0_band_11:float',
#        'lambda0_band_12:float', 'lambda0_band_13:float',
#        'lambda0_band_14:float', 'lambda0_band_15:float',
#        'lambda0_band_16:float', 'lambda0_band_17:float',
#        'lambda0_band_18:float', 'lambda0_band_19:float',
#        'lambda0_band_20:float', 'lambda0_band_21:float',
#        'solar_flux_band_1:float', 'solar_flux_band_2:float',
#        'solar_flux_band_3:float', 'solar_flux_band_4:float',
#        'solar_flux_band_5:float', 'solar_flux_band_6:float',
#        'solar_flux_band_7:float', 'solar_flux_band_8:float',
#        'solar_flux_band_9:float', 'solar_flux_band_10:float',
#        'solar_flux_band_11:float', 'solar_flux_band_12:float',
#        'solar_flux_band_13:float', 'solar_flux_band_14:float',
#        'solar_flux_band_15:float', 'solar_flux_band_16:float',
#        'solar_flux_band_17:float', 'solar_flux_band_18:float',
#        'solar_flux_band_19:float', 'solar_flux_band_20:float',
#        'solar_flux_band_21:float', 'ADG443_NN:float',
#        'ADG443_NN_err:float', 'IWV:float', 'IWV_err:float', 'PAR:float',
#        'PAR_err:float', 'KD490_M07:float', 'KD490_M07_err:float',
#        'TSM_NN:float', 'TSM_NN_err:float', 'A865:float', 'A865_err:float',
#        'T865:float', 'T865_err:float', 'WQSF_lsb:double',
#        'WQSF_msb:double', 'TP_latitude:float', 'TP_longitude:float',
#        'OAA:float', 'OZA:float', 'SAA:float', 'SZA:float',
#        'atmospheric_temperature_profile_pressure_level_1:float',
#        'atmospheric_temperature_profile_pressure_level_2:float',
#        'atmospheric_temperature_profile_pressure_level_3:float',
#        'atmospheric_temperature_profile_pressure_level_4:float',
#        'atmospheric_temperature_profile_pressure_level_5:float',
#        'atmospheric_temperature_profile_pressure_level_6:float',
#        'atmospheric_temperature_profile_pressure_level_7:float',
#        'atmospheric_temperature_profile_pressure_level_8:float',
#        'atmospheric_temperature_profile_pressure_level_9:float',
#        'atmospheric_temperature_profile_pressure_level_10:float',
#        'atmospheric_temperature_profile_pressure_level_11:float',
#        'atmospheric_temperature_profile_pressure_level_12:float',
#        'atmospheric_temperature_profile_pressure_level_13:float',
#        'atmospheric_temperature_profile_pressure_level_14:float',
#        'atmospheric_temperature_profile_pressure_level_15:float',
#        'atmospheric_temperature_profile_pressure_level_16:float',
#        'atmospheric_temperature_profile_pressure_level_17:float',
#        'atmospheric_temperature_profile_pressure_level_18:float',
#        'atmospheric_temperature_profile_pressure_level_19:float',
#        'atmospheric_temperature_profile_pressure_level_20:float',
#        'atmospheric_temperature_profile_pressure_level_21:float',
#        'atmospheric_temperature_profile_pressure_level_22:float',
#        'atmospheric_temperature_profile_pressure_level_23:float',
#        'atmospheric_temperature_profile_pressure_level_24:float',
#        'atmospheric_temperature_profile_pressure_level_25:float',
#        'horizontal_wind_vector_1:float', 'horizontal_wind_vector_2:float',
#        'humidity:float', 'sea_level_pressure:float',
#        'total_columnar_water_vapour:float', 'total_ozone:float'],
#       dtype=object)

# %%
# Ok, time for data-cleaning

# Columns to keep
keep = ['Oa01_reflectance:float',
       'Oa02_reflectance:float',
       'Oa03_reflectance:float',
       'Oa04_reflectance:float',
       'Oa05_reflectance:float',
       'Oa06_reflectance:float',
       'Oa07_reflectance:float',
       'Oa08_reflectance:float',
       'Oa09_reflectance:float',
       'Oa10_reflectance:float',
       'Oa11_reflectance:float',
       'Oa12_reflectance:float',
       'Oa16_reflectance:float',
       'Oa17_reflectance:float',
       'Oa18_reflectance:float',
       'Oa21_reflectance:float',
       'latitude:double', 'longitude:double']

# Drop columns not present in the list
df = df.filter(keep)
print('remaining columns: ',len(df.columns))

# target pixels shoul have lon/lat data, zero values must be dropped
print('lon != 0: ',np.count_nonzero(subset_data['longitude:double']))
print('lat != 0: ',np.count_nonzero(subset_data['latitude:double']))
# Out:
# remaining columns:  18
# lon != 0:  1273
# lat != 0:  1273

# %%
# number of rows:
len(df)
# Out:
# 52624

# %%
# Get names of indexes for which column LON has value 0
indexNames = df[ df['longitude:double'] == 0 ].index
 
# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)

# remaining meaningful data
len(df)
# Out:
# 1273

# %%
df['Oa08_reflectance:float'].describe()
# Out:
# count    1273.000000
# mean        0.944845
# std         0.204551
# min         0.001953
# 25%         1.000018
# 50%         1.000018
# 75%         1.000018
# max         1.000018
# Name: Oa08_reflectance:float, dtype: float64

# %%
# Assuming the reflectance of water pixels should not be above 0.16, we will drop using this threshold
indexNames = df[ df['Oa08_reflectance:float'] > 0.16 ].index

# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)

len(df)
# Out:
# 23

# %%
df['Oa08_reflectance:float'].describe()
# Out:
# count    23.000000
# mean      0.091856
# std       0.043781
# min       0.001953
# 25%       0.060475
# 50%       0.098105
# 75%       0.126579
# max       0.157689
# Name: Oa08_reflectance:float, dtype: float64

# %%
for col in df.columns:
    print(col,' mean: ',df[col].mean())
# Out:
# Oa01_reflectance:float  mean:  -0.022173687321739136
# Oa02_reflectance:float  mean:  -0.01634836662608696
# Oa03_reflectance:float  mean:  0.002863168048565217
# Oa04_reflectance:float  mean:  0.02643433816521739
# Oa05_reflectance:float  mean:  0.03863988393478261
# Oa06_reflectance:float  mean:  0.07309820192608694
# Oa07_reflectance:float  mean:  0.08608157157391305
# Oa08_reflectance:float  mean:  0.09185593897826087
# Oa09_reflectance:float  mean:  0.0931034827173913
# Oa10_reflectance:float  mean:  0.09487329081739132
# Oa11_reflectance:float  mean:  0.11909967891304349
# Oa12_reflectance:float  mean:  0.1578587186956522
# Oa16_reflectance:float  mean:  0.1554647411304348
# Oa17_reflectance:float  mean:  0.15144027813500002
# Oa18_reflectance:float  mean:  0.1509912592130435
# Oa21_reflectance:float  mean:  0.14082859569565215
# latitude:double  mean:  -3.40950404347826
# longitude:double  mean:  -60.727664695652166

# %%
# another way of doing it excluding NA-s
df.mean(skipna = True)
# Out:
# Oa01_reflectance:float   -0.022174
# Oa02_reflectance:float   -0.016348
# Oa03_reflectance:float    0.002863
# Oa04_reflectance:float    0.026434
# Oa05_reflectance:float    0.038640
# Oa06_reflectance:float    0.073098
# Oa07_reflectance:float    0.086082
# Oa08_reflectance:float    0.091856
# Oa09_reflectance:float    0.093103
# Oa10_reflectance:float    0.094873
# Oa11_reflectance:float    0.119100
# Oa12_reflectance:float    0.157859
# Oa16_reflectance:float    0.155465
# Oa17_reflectance:float    0.151440
# Oa18_reflectance:float    0.150991
# Oa21_reflectance:float    0.140829
# dtype: float64

# %%
# lets also drop the lat/lon columns
df = df.drop(['latitude:double','longitude:double'], axis=1)
df.columns
# Out:
# Index(['Oa01_reflectance:float', 'Oa02_reflectance:float',
#        'Oa03_reflectance:float', 'Oa04_reflectance:float',
#        'Oa05_reflectance:float', 'Oa06_reflectance:float',
#        'Oa07_reflectance:float', 'Oa08_reflectance:float',
#        'Oa09_reflectance:float', 'Oa10_reflectance:float',
#        'Oa11_reflectance:float', 'Oa12_reflectance:float',
#        'Oa16_reflectance:float', 'Oa17_reflectance:float',
#        'Oa18_reflectance:float', 'Oa21_reflectance:float'],
#       dtype='object')

# %%
# looks reasonable, now lets convert it into a function

# %%
def get_mean_and_clean(image_path):
    # read text file and convert to pandas dataframe
    df = pd.read_csv(image_path, sep='\t', skiprows=1)
    # # Columns to keep
    keep = ['Oa01_reflectance:float',
            'Oa02_reflectance:float',
            'Oa03_reflectance:float',
            'Oa04_reflectance:float',
            'Oa05_reflectance:float',
            'Oa06_reflectance:float',
            'Oa07_reflectance:float',
            'Oa08_reflectance:float',
            'Oa09_reflectance:float',
            'Oa10_reflectance:float',
            'Oa11_reflectance:float',
            'Oa12_reflectance:float',
            'Oa16_reflectance:float',
            'Oa17_reflectance:float',
            'Oa18_reflectance:float',
            'Oa21_reflectance:float',
            'latitude:double', 
            'longitude:double']
    # Drop columns not present in the list
    df = df.filter(keep)
    # Get names of indexes for which column LON has value 0
    indexNames = df[ df['longitude:double'] == 0 ].index
    # Delete these row indexes from dataFrame
    df.drop(indexNames , inplace=True)
    # Assuming the reflectance of water pixels should not be above 0.16, we will drop using this threshold
    indexNames = df[ df['Oa08_reflectance:float'] > 0.16 ].index
    # Delete these row indexes from dataFrame
    df.drop(indexNames , inplace=True)
    # drop lon/lat columns
    df = df.drop(['latitude:double','longitude:double'], axis=1)
    return df.mean(skipna = True)

# %%
work_dir = '/d_drive_data/processing/MANACAPURU/'

s3frbr_output_files = os.listdir(work_dir)

file_name = os.path.join(work_dir, s3frbr_output_files[0])

file_name
# Out:
# '/d_drive_data/processing/MANACAPURU/S3A_OL_2_WFR____20190317T140455_20190317T140755_20190318T205900_0179_042_281_3060_MAR_O_NT_002_subset.txt'

# %%
list(get_mean_and_clean(file_name))
# Out:
# [0.0666909620680019,
#  0.06416661192154745,
#  0.06885995815251708,
#  0.07659271492801177,
#  0.08243754483775713,
#  0.10251704468003907,
#  0.1171125920910626,
#  0.12345849298973555,
#  0.12519114330585707,
#  0.1257604561147405,
#  0.11963789255537711,
#  0.0954628028701274,
#  0.10139603174946143,
#  0.08363587306923703,
#  0.07873538347696961,
#  0.06255952077365226]

# %%
s3frbr_output_files[0]
# Out:
# 'S3A_OL_2_WFR____20190317T140455_20190317T140755_20190318T205900_0179_042_281_3060_MAR_O_NT_002_subset.txt'

# %%
print(s3frbr_output_files[0][16:31],'\n',datetime.strptime(s3frbr_output_files[0][16:31], '%Y%m%dT%H%M%S'))
# Out:
# 20190317T140455
#  2019-03-17 14:04:55

# %% [markdown]
# ## Repeating for every file

# %%
# start timer
utils.tic()

Oa01_reflectance_tms = []
Oa02_reflectance_tms = []
Oa03_reflectance_tms = []
Oa04_reflectance_tms = []
Oa05_reflectance_tms = []
Oa06_reflectance_tms = []
Oa07_reflectance_tms = []
Oa08_reflectance_tms = []
Oa09_reflectance_tms = []
Oa10_reflectance_tms = []
Oa11_reflectance_tms = []
Oa12_reflectance_tms = []
Oa16_reflectance_tms = []
Oa17_reflectance_tms = []
Oa18_reflectance_tms = []
Oa21_reflectance_tms = []
datetime_labels = []
string_labels = []

work_dir = '/d_drive_data/processing/MANACAPURU/'

s3frbr_output_files = os.listdir(work_dir)

total = len(s3frbr_output_files)

for n, image in enumerate(s3frbr_output_files):
    
    print(f'Extracting image {n+1}/{total}\n')
    file_name = os.path.join(work_dir, image)
    dtlbl = datetime.strptime(image[16:31], '%Y%m%dT%H%M%S')
    strlbl = image[16:31]
    Oa01, Oa02, Oa03, Oa04, Oa05, Oa06, Oa07, Oa08, Oa09, Oa10, Oa11, Oa12, Oa16, Oa17, Oa18, Oa21 = list(get_mean_and_clean(file_name))

    Oa01_reflectance_tms.append(Oa01)
    Oa02_reflectance_tms.append(Oa02)
    Oa03_reflectance_tms.append(Oa03)
    Oa04_reflectance_tms.append(Oa04)
    Oa05_reflectance_tms.append(Oa05)
    Oa06_reflectance_tms.append(Oa06)
    Oa07_reflectance_tms.append(Oa07)
    Oa08_reflectance_tms.append(Oa08)
    Oa09_reflectance_tms.append(Oa09)
    Oa10_reflectance_tms.append(Oa10)
    Oa11_reflectance_tms.append(Oa11)
    Oa12_reflectance_tms.append(Oa12)
    Oa16_reflectance_tms.append(Oa16)
    Oa17_reflectance_tms.append(Oa17)
    Oa18_reflectance_tms.append(Oa18)
    Oa21_reflectance_tms.append(Oa21)
    datetime_labels.append(dtlbl)
    string_labels.append(strlbl)

# stop timer
t_hour, t_min, t_sec = utils.tac()
print(f'\nDone in {t_hour}h:{t_min}m:{t_sec}s')
# Out:
# Extracting image 1/209
#
# Extracting image 2/209
#
# Extracting image 3/209
#
# Extracting image 4/209
#
# Extracting image 5/209
#
# Extracting image 6/209
#
# Extracting image 7/209
#
# Extracting image 8/209
#
# Extracting image 9/209
#
# Extracting image 10/209
#
# Extracting image 11/209
#
# Extracting image 12/209
#
# Extracting image 13/209
#
# Extracting image 14/209
#
# Extracting image 15/209
#
# Extracting image 16/209
#
# Extracting image 17/209
#
# Extracting image 18/209
#
# Extracting image 19/209
#
# Extracting image 20/209
#
# Extracting image 21/209
#
# Extracting image 22/209
#
# Extracting image 23/209
#
# Extracting image 24/209
#
# Extracting image 25/209
#
# Extracting image 26/209
#
# Extracting image 27/209
#
# Extracting image 28/209
#
# Extracting image 29/209
#
# Extracting image 30/209
#
# Extracting image 31/209
#
# Extracting image 32/209
#
# Extracting image 33/209
#
# Extracting image 34/209
#
# Extracting image 35/209
#
# Extracting image 36/209
#
# Extracting image 37/209
#
# Extracting image 38/209
#
# Extracting image 39/209
#
# Extracting image 40/209
#
# Extracting image 41/209
#
# Extracting image 42/209
#
# Extracting image 43/209
#
# Extracting image 44/209
#
# Extracting image 45/209
#
# Extracting image 46/209
#
# Extracting image 47/209
#
# Extracting image 48/209
#
# Extracting image 49/209
#
# Extracting image 50/209
#
# Extracting image 51/209
#
# Extracting image 52/209
#
# Extracting image 53/209
#
# Extracting image 54/209
#
# Extracting image 55/209
#
# Extracting image 56/209
#
# Extracting image 57/209
#
# Extracting image 58/209
#
# Extracting image 59/209
#
# Extracting image 60/209
#
# Extracting image 61/209
#
# Extracting image 62/209
#
# Extracting image 63/209
#
# Extracting image 64/209
#
# Extracting image 65/209
#
# Extracting image 66/209
#
# Extracting image 67/209
#
# Extracting image 68/209
#
# Extracting image 69/209
#
# Extracting image 70/209
#
# Extracting image 71/209
#
# Extracting image 72/209
#
# Extracting image 73/209
#
# Extracting image 74/209
#
# Extracting image 75/209
#
# Extracting image 76/209
#
# Extracting image 77/209
#
# Extracting image 78/209
#
# Extracting image 79/209
#
# Extracting image 80/209
#
# Extracting image 81/209
#
# Extracting image 82/209
#
# Extracting image 83/209
#
# Extracting image 84/209
#
# Extracting image 85/209
#
# Extracting image 86/209
#
# Extracting image 87/209
#
# Extracting image 88/209
#
# Extracting image 89/209
#
# Extracting image 90/209
#
# Extracting image 91/209
#
# Extracting image 92/209
#
# Extracting image 93/209
#
# Extracting image 94/209
#
# Extracting image 95/209
#
# Extracting image 96/209
#
# Extracting image 97/209
#
# Extracting image 98/209
#
# Extracting image 99/209
#
# Extracting image 100/209
#
# Extracting image 101/209
#
# Extracting image 102/209
#
# Extracting image 103/209
#
# Extracting image 104/209
#
# Extracting image 105/209
#
# Extracting image 106/209
#
# Extracting image 107/209
#
# Extracting image 108/209
#
# Extracting image 109/209
#
# Extracting image 110/209
#
# Extracting image 111/209
#
# Extracting image 112/209
#
# Extracting image 113/209
#
# Extracting image 114/209
#
# Extracting image 115/209
#
# Extracting image 116/209
#
# Extracting image 117/209
#
# Extracting image 118/209
#
# Extracting image 119/209
#
# Extracting image 120/209
#
# Extracting image 121/209
#
# Extracting image 122/209
#
# Extracting image 123/209
#
# Extracting image 124/209
#
# Extracting image 125/209
#
# Extracting image 126/209
#
# Extracting image 127/209
#
# Extracting image 128/209
#
# Extracting image 129/209
#
# Extracting image 130/209
#
# Extracting image 131/209
#
# Extracting image 132/209
#
# Extracting image 133/209
#
# Extracting image 134/209
#
# Extracting image 135/209
#
# Extracting image 136/209
#
# Extracting image 137/209
#
# Extracting image 138/209
#
# Extracting image 139/209
#
# Extracting image 140/209
#
# Extracting image 141/209
#
# Extracting image 142/209
#
# Extracting image 143/209
#
# Extracting image 144/209
#
# Extracting image 145/209
#
# Extracting image 146/209
#
# Extracting image 147/209
#
# Extracting image 148/209
#
# Extracting image 149/209
#
# Extracting image 150/209
#
# Extracting image 151/209
#
# Extracting image 152/209
#
# Extracting image 153/209
#
# Extracting image 154/209
#
# Extracting image 155/209
#
# Extracting image 156/209
#
# Extracting image 157/209
#
# Extracting image 158/209
#
# Extracting image 159/209
#
# Extracting image 160/209
#
# Extracting image 161/209
#
# Extracting image 162/209
#
# Extracting image 163/209
#
# Extracting image 164/209
#
# Extracting image 165/209
#
# Extracting image 166/209
#
# Extracting image 167/209
#
# Extracting image 168/209
#
# Extracting image 169/209
#
# Extracting image 170/209
#
# Extracting image 171/209
#
# Extracting image 172/209
#
# Extracting image 173/209
#
# Extracting image 174/209
#
# Extracting image 175/209
#
# Extracting image 176/209
#
# Extracting image 177/209
#
# Extracting image 178/209
#
# Extracting image 179/209
#
# Extracting image 180/209
#
# Extracting image 181/209
#
# Extracting image 182/209
#
# Extracting image 183/209
#
# Extracting image 184/209
#
# Extracting image 185/209
#
# Extracting image 186/209
#
# Extracting image 187/209
#
# Extracting image 188/209
#
# Extracting image 189/209
#
# Extracting image 190/209
#
# Extracting image 191/209
#
# Extracting image 192/209
#
# Extracting image 193/209
#
# Extracting image 194/209
#
# Extracting image 195/209
#
# Extracting image 196/209
#
# Extracting image 197/209
#
# Extracting image 198/209
#
# Extracting image 199/209
#
# Extracting image 200/209
#
# Extracting image 201/209
#
# Extracting image 202/209
#
# Extracting image 203/209
#
# Extracting image 204/209
#
# Extracting image 205/209
#
# Extracting image 206/209
#
# Extracting image 207/209
#
# Extracting image 208/209
#
# Extracting image 209/209
#
#
# Done in 0h:1m:50s

# %%
plt.rcParams['figure.figsize'] = [12, 6] 
plt.plot(Oa08_reflectance_tms)
